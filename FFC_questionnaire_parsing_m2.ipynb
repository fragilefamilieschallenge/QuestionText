# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import numpy as np

# %%
import sys
sys.getdefaultencoding()
# Out:
# 'utf-8'

# %% [markdown]
# Open the questionnaire file (word document version of the questionnaire saved as html):

# %%
questionnaire_file = open("FF_m2_Questionnaire.htm", "r")

# %%
soup=BeautifulSoup(questionnaire_file, "html.parser")

# %%
ps=[p for p in soup.find_all('p')]

# %% [markdown]
# Opening the excel file with all the questions for p6, using the pandas python library:

# %%
df=pd.read_excel("FFCm2.xlsx") #this is an excel file with all the questions for p6

# %%
df.head()
# Out:
#    position   name                                             varlab
# 0      1842   m2a3  How much of the time does the child live with ...
# 1      1843   m2a4  How many months ago did (he/she) stop living w...
# 2      1844  m2a4a                Who does child (usually) live with?
# 3      1845  m2a4b  About how long has child been living there (mo...
# 4      1846  m2a4c  Do you expect the child to live with you (agai...

# %%
df.shape
# Out:
# (812, 3)

# %%
reg = re.compile(r'(?P<section>[A-Za-z]*\d*)(?P<rest>.*)')

def format_q_num(name):
    """takes in the question numbers in the name column and outputs them in the format
    they appear in the text"""
    name=name.lstrip('m2')
    name=reg.search(name)
    section=name.group('section').upper()
    rest=name.group('rest').upper()
    return section+rest

# %%
df['question_number']=df.name.apply(lambda x: format_q_num(x))

# %%
df['multiple_answers']=df.question_number.apply(lambda x: 1 if re.match('[A-Z]\d*[A-Z]\d*[A-Z]',x) else 0) 
#adds a column where 1 indicates that it is one of the questions with multiple entries in the data frame
#I think these are mostly (only?) the "select all that apply" questions

# %%
df[60:70]
# Out:
#     position    name                                             varlab  \
# 60      1902  m2b5c1     How much did child weigh on that day?-(Pounds)
# 61      1903  m2b5c2     How much did child weigh on that day?-(Ounces)
# 62      1904    m2b6  How many times since birth has child been to h...
# 63      1905    m2b7  How many times since birth has child been to h...
# 64      1906   mx2b7  TCO-How many times has child been seen by heal...
# 65      1907   m2b7a  How many times since birth has child been to h...
# 66      1908    m2b8  How many times since birth has child been to e...
# 67      1909   m2b8a  How many visits to emergency room for accident...
# 68      1910    m2b9  Since leaving the hospital at birth, has child...
# 69      1911   m2b10  Since child was born, how many times has he/sh...
#
#    question_number  multiple_answers
# 60            B5C1                 0
# 61            B5C2                 0
# 62              B6                 0
# 63              B7                 0
# 64            X2B7                 0
# 65             B7A                 0
# 66              B8                 0
# 67             B8A                 0
# 68              B9                 0
# 69             B10                 0

# %%
def find_question(q_number):
    """finds where the question number appears in the text - only if it only appears once"""
    ps_text = []
    ps_idx = []
    ps_startswith = []
    for idx, p in enumerate(ps):
        if q_number+"." in p.get_text():
            if p.get_text().lstrip().startswith(q_number+"."):
                ps_text.append(p.get_text().lstrip())
                ps_idx.append(idx)
            else:
                start = p.get_text().find(q_number+'.')
                ps_text.append(p.get_text().lstrip()[start:])
                ps_idx.append(idx)
    if len(ps_idx)!=1:
        return np.nan, np.nan
    else:
        return ps_text[0].replace("\n"," ").strip(), ps_idx[0]

# %%
b17a = ps[727:729]
b17a
# Out:
# [<p class="MsoNormal"><span style='font-size:11.0pt;font-family:"Arial",sans-serif'>B17A.</span></p>,
#  <p class="MsoNormal"><span style='font-size:11.0pt;font-family:"Arial",sans-serif;
#    color:windowtext'>(He/She) tends to be shy.................... </span></p>]

# %%
def find_probe(q_number):
    probe = re.findall('[A-Z]{,1}\d{,2}', q_number)[0]
    return find_question(probe)[0]

# %%
for i in range(len(df.question_number)):
    q_number = df.loc[i,'question_number']
    if re.match('^[A-Z]{,1}\d{,2}', q_number):
        df.loc[i,'probe'] = find_probe(q_number)
    else:
        df.loc[i,'probe'] = "None"

# %%
df['ps_text'], df['ps_idx'] = zip(*df['question_number'].map(find_question))

# %%
df.head(10)
# Out:
#    position   name                                             varlab  \
# 0      1842   m2a3  How much of the time does the child live with ...
# 1      1843   m2a4  How many months ago did (he/she) stop living w...
# 2      1844  m2a4a                Who does child (usually) live with?
# 3      1845  m2a4b  About how long has child been living there (mo...
# 4      1846  m2a4c  Do you expect the child to live with you (agai...
# 5      1847  m2a4d  How many days did you see the child in the pas...
# 6      1848   m2a6  What was your relationship with father when ch...
# 7      1849  m2a6b  What was your relationship with father when ch...
# 8      1850  m2a6c  When child was born, were you and father livin...
# 9      1851   m2a7         What is your relationship with father now?
#
#   question_number  multiple_answers  \
# 0              A3                 0
# 1              A4                 0
# 2             A4A                 0
# 3             A4B                 0
# 4             A4C                 0
# 5             A4D                 0
# 6              A6                 0
# 7             A6B                 0
# 8             A6C                 0
# 9              A7                 0
#
#                                                probe  \
# 0                                                NaN
# 1  A4.           How many months ago did (he/she)...
# 2  A4.           How many months ago did (he/she)...
# 3  A4.           How many months ago did (he/she)...
# 4  A4.           How many months ago did (he/she)...
# 5  A4.           How many months ago did (he/she)...
# 6  A6.           Next, I have a few questions abo...
# 7  A6.           Next, I have a few questions abo...
# 8  A6.           Next, I have a few questions abo...
# 9  A7.           What is your relationship with (...
#
#                                              ps_text  ps_idx
# 0                                                NaN     NaN
# 1  A4.           How many months ago did (he/she)...   147.0
# 2  A4A.        Who does (CHILD) (usually) live with?   158.0
# 3  A4B.        About how long has (CHILD) been li...   170.0
# 4  A4C.        Do you expect (CHILD) to live with...   179.0
# 5  A4D.        About how many days did you see (C...   185.0
# 6  A6.           Next, I have a few questions abo...   193.0
# 7  A6B.        What was your relationship with (F...   217.0
# 8  A6C.        When (CHILD) was born, were you an...   229.0
# 9  A7.           What is your relationship with (...   238.0

# %%
np.isnan(df.ps_idx).sum() #number of questions where the question number doesn't appear or appears more than once
# Out:
# 316

# %%
#get index of <p> tag for the next question so we can split the questions (can't just shift because some questions have more than one answer or missing values)
all_idx=np.array(df.ps_idx)
all_idx=all_idx[~np.isnan(all_idx)]
all_idx=np.append(all_idx, [len(ps)])
df['ps_idx_next']=df.ps_idx.apply(lambda x: all_idx[all_idx > x].min() if ~np.isnan(x) else np.nan)

# %%
consequitivedots = re.compile(r'\.{3,}')

# %%
def clean_text(string):
    return string.replace("\n"," ").strip()

def get_pairs(p):
    if re.match('^[a-z]{1}', p.get_text().split('..')[0]):
        if re.match('[()]{1}', p.get_text().split('..')[-1]):
            pairs = [p.find_previous('p').get_text() + ' ' + p.get_text().split('..')[0], p.get_text().split("(")[0].split('..')[-1]]
        else:
            pairs = [p.find_previous('p').get_text() + ' ' + p.get_text().split('..')[0], p.get_text().split('..')[-1]]
    else:
        if re.match('[()]{1}', p.get_text().split('.')[-1]):
            pairs = [p.get_text().split('..')[0], p.get_text().split("(")[0].split('..')[-1] ]
        else:
            pairs = [p.get_text().split('..')[0], p.get_text().split('..')[-1]]
    pairs = [clean_text(text) for text in pairs]
    return pairs
        
def get_answers(start_idx,stop_idx):
    if np.isnan(start_idx) or np.isnan(stop_idx):
        return ([],0)
    else:
        answers = [p for p in ps[int(start_idx):int(stop_idx)] if len(p.find_all(string = consequitivedots))>0]
        answers = [get_pairs(a) for a in answers]
        return(answers, len(answers))

# %%
df['answers'], df['n_answers'] = zip(*map(get_answers, df['ps_idx'], df['ps_idx_next']))

# %%
(df['answers'][20])
# Out:
# []

# %%
x = 0
while x < len(df.answers):
    ans = df.answers[x]
    for i in range(len(ans)): #for each answer choice,
        s = ans[i][1]        # store number string
        a = re.sub('è',' --> ', s) # sub the arrow in for skip pattern
        t = (ans[i][0],a) # create a new tuple with arrow
        ans[i] = t
    for y in range(len(ans)):
        df.loc[x,'val{0}'.format(y)] = ans[y][1] #create new 'val(y)' column
        df.loc[x,'lab{0}'.format(y)] = ans[y][0] #create new 'lab(y)' column
        
    x += 1

# %%
values = []
for i in range(0,18):
    values = values + ['val{0}'.format(i)]
    i += 1
for v in values:
    df[v] = df[v].map(lambda x: str(x))
    df[v] = df[v].map(lambda x: x.lstrip('.').strip())

# %%
df['val0']
# Out:
# 0                    nan
# 1                    -10
# 2                      1
# 3                      0
# 4                      1
# 5                    nan
# 6      1  -->  GO TO A6C
# 7                      1
# 8                      1
# 9                      1
# 10                     1
# 11     1  -->  GO TO A8A
# 12                     0
# 13                   nan
# 14                     1
# 15                     1
# 16                   nan
# 17                   nan
# 18                     1
# 19                   nan
# 20                   nan
# 21                     1
# 22                   nan
# 23                   nan
# 24                     1
# 25                     1
# 26                     1
# 27                   nan
# 28                   nan
# 29                   nan
#              ...
# 782                  nan
# 783                  nan
# 784                  nan
# 785                  nan
# 786                  nan
# 787                  nan
# 788                   -2
# 789                    1
# 790                    1
# 791                   -2
# 792                    1
# 793                    1
# 794                    1
# 795                    1
# 796                    1
# 797                    1
# 798                    1
# 799                    0
# 800                    0
# 801                    1
# 802                    1
# 803                    1
# 804                    1
# 805    1  -->  GO TO L14
# 806                    1
# 807                    1
# 808                    1
# 809                    1
# 810                    0
# 811                    0
# Name: val0, Length: 812, dtype: object

# %%
i = 0
while i < len(df.ps_text):
    if df.multiple_answers[i] == 1:
        df.loc[i,'val0'] = '1'
        df.loc[i,'lab0'] = 'YES'
        df.loc[i,'val1'] = '2'
        df.loc[i,'lab1'] = 'NO'
    i += 1

# %%
df.drop(['answers','n_answers','question_number','ps_idx','ps_idx_next'],axis=1,inplace=True)

# %%
df.head(20)
# Out:
#     position     name                                             varlab  \
# 0       1842     m2a3  How much of the time does the child live with ...
# 1       1843     m2a4  How many months ago did (he/she) stop living w...
# 2       1844    m2a4a                Who does child (usually) live with?
# 3       1845    m2a4b  About how long has child been living there (mo...
# 4       1846    m2a4c  Do you expect the child to live with you (agai...
# 5       1847    m2a4d  How many days did you see the child in the pas...
# 6       1848     m2a6  What was your relationship with father when ch...
# 7       1849    m2a6b  What was your relationship with father when ch...
# 8       1850    m2a6c  When child was born, were you and father livin...
# 9       1851     m2a7         What is your relationship with father now?
# 10      1852    m2a7a      Are you and father currently living together?
# 11      1853   m2a7a1  Int Chk: Are mother and father married and liv...
# 12      1854   m2a7a2  How many nights a week do you and father usual...
# 13      1855   m2a7b2                        When did father die? (Year)
# 14      1856    m2a7c                       What was the cause of death?
# 15      1857    m2a8a  Int chk: Were mother and father ever married t...
# 16      1858  m2a8a1a       When did you and father get married? (Month)
# 17      1859  m2a8a1b        When did you and father get married? (Year)
# 18      1860    m2a8b  Int Chk: Were mother and father living togethe...
# 19      1861  m2a8b1a  When did you and father start living together?...
#
#     multiple_answers                                              probe  \
# 0                  0                                                NaN
# 1                  0  A4.           How many months ago did (he/she)...
# 2                  0  A4.           How many months ago did (he/she)...
# 3                  0  A4.           How many months ago did (he/she)...
# 4                  0  A4.           How many months ago did (he/she)...
# 5                  0  A4.           How many months ago did (he/she)...
# 6                  0  A6.           Next, I have a few questions abo...
# 7                  0  A6.           Next, I have a few questions abo...
# 8                  0  A6.           Next, I have a few questions abo...
# 9                  0  A7.           What is your relationship with (...
# 10                 0  A7.           What is your relationship with (...
# 11                 0  A7.           What is your relationship with (...
# 12                 0  A7.           What is your relationship with (...
# 13                 0  A7.           What is your relationship with (...
# 14                 0  A7.           What is your relationship with (...
# 15                 0                                                NaN
# 16                 1                                                NaN
# 17                 1                                                NaN
# 18                 0                                                NaN
# 19                 1                                                NaN
#
#                                               ps_text               val0  \
# 0                                                 NaN                nan
# 1   A4.           How many months ago did (he/she)...                -10
# 2   A4A.        Who does (CHILD) (usually) live with?                  1
# 3   A4B.        About how long has (CHILD) been li...                  0
# 4   A4C.        Do you expect (CHILD) to live with...                  1
# 5   A4D.        About how many days did you see (C...                nan
# 6   A6.           Next, I have a few questions abo...  1  -->  GO TO A6C
# 7   A6B.        What was your relationship with (F...                  1
# 8   A6C.        When (CHILD) was born, were you an...                  1
# 9   A7.           What is your relationship with (...                  1
# 10  A7A.        Are you and (FATHER) currently liv...                  1
# 11  A7A1.      ARE MOTHER AND FATHER MARRIED AND L...  1  -->  GO TO A8A
# 12  A7A2.      How many nights a week do you and (...                  0
# 13                                                NaN                nan
# 14       A7C.        What was the cause of his death?                  1
# 15  A8A.        WERE MOTHER AND FATHER EVER MARRIE...                  1
# 16                                                NaN                  1
# 17                                                NaN                  1
# 18  A8B.        WERE MOTHER AND FATHER LIVING TOGE...                  1
# 19                                                NaN                  1
#
#                                lab0                val1  \
# 0                               NaN                 nan
# 1   (CHILD) MOST OR ALL OF THE TIME                 nan
# 2                 BIOLOGICAL FATHER                   2
# 3               LESS THAN ONE MONTH                 nan
# 4                               YES                   2
# 5                               NaN                 nan
# 6                          Married,   2  -->  GO TO A6C
# 7                          Married,                   2
# 8          All or most of the time,                   2
# 9                          Married,                   2
# 10         All or most of the time,                   2
# 11                              YES                   2
# 12                             NONE  -1  -->  GO TO A8A
# 13                              NaN                 nan
# 14                    WON’T DISCUSS                   2
# 15                              YES   2  -->  GO TO A8B
# 16                              YES                   2
# 17                              YES                   2
# 18                              YES   2  -->  GO TO A8C
# 19                              YES                   2
#
#                        lab1  ...   val104 lab104 val105 lab105 val106 lab106  \
# 0                       NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 1                       NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 2   MATERNAL GRANDPARENT(S)  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 3                       NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 4                        NO  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 5                       NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 6    Romantically involved,  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 7    Romantically involved,  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 8         Some of the time,  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 9    Romantically involved,  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 10        Some of the time,  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 11                       NO  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 12                  REFUSED  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 13                      NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 14  ILLNESS (NOT SPECIFIED)  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 15                       NO  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 16                       NO  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 17                       NO  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 18                       NO  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 19                       NO  ...      NaN    NaN    NaN    NaN    NaN    NaN
#
#    val107 lab107 val108 lab108
# 0     NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN
# 5     NaN    NaN    NaN    NaN
# 6     NaN    NaN    NaN    NaN
# 7     NaN    NaN    NaN    NaN
# 8     NaN    NaN    NaN    NaN
# 9     NaN    NaN    NaN    NaN
# 10    NaN    NaN    NaN    NaN
# 11    NaN    NaN    NaN    NaN
# 12    NaN    NaN    NaN    NaN
# 13    NaN    NaN    NaN    NaN
# 14    NaN    NaN    NaN    NaN
# 15    NaN    NaN    NaN    NaN
# 16    NaN    NaN    NaN    NaN
# 17    NaN    NaN    NaN    NaN
# 18    NaN    NaN    NaN    NaN
# 19    NaN    NaN    NaN    NaN
#
# [20 rows x 224 columns]

# %%
df.to_csv(path_or_buf = "m2Qtext.csv")
