# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import numpy as np

# %%
import sys
sys.getdefaultencoding()
# Out:
# 'utf-8'

# %% [markdown]
# Open the questionnaire file (word document version of the questionnaire saved as html):

# %%
questionnaire_file = open("FF_m3_Questionnaire.htm", "r")

# %%
soup=BeautifulSoup(questionnaire_file, "html.parser")

# %%
ps=[p for p in soup.find_all('p')]

# %%
ps[108:111]
# Out:
# [<p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             MATERNAL GRANDPARENT(S)...................... 2
#  </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             PATERNAL GRANDPARENT(S)...................... 3
#  </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             OTHER RELATIVE(S)......................................... 4
#  </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>]

# %% [markdown]
# Opening the excel file with all the questions for p6, using the pandas python library:

# %%
df=pd.read_excel("FFCm3.xlsx") #this is an excel file with all the questions for p6

# %%
df.head()
# Out:
#    position    name                                             varlab
# 0      3916    m3a2  How much of the time does the child live with ...
# 1      3917    m3a3  How many months ago did he/she stop living wit...
# 2      3918   m3a3a                  Who does child usually live with?
# 3      3919   m3a3b         Are child's foster parents related to you?
# 4      3920  m3a3b1  Does (person in A3A) receive any payment for t...

# %%
df.shape
# Out:
# (1035, 3)

# %%
reg = re.compile(r'(?P<section>[A-Za-z]*\d*)(?P<rest>.*)')

def format_q_num(name):
    """takes in the question numbers in the name column and outputs them in the format
    they appear in the text"""
    name=name.lstrip('m3').split('_')[0] 
    name=reg.search(name)
    section=name.group('section').upper()
    rest=name.group('rest').upper()
    return section+rest

# %%
df['question_number']=df.name.apply(lambda x: format_q_num(x))

# %%
df['multiple_answers']=df.name.apply(lambda x: 1 if "_" in x else 0) 
#adds a column where 1 indicates that it is one of the questions with multiple entries in the data frame
#I think these are mostly (only?) the "select all that apply" questions

# %%
df.head(20)
# Out:
#     position    name                                             varlab  \
# 0       3916    m3a2  How much of the time does the child live with ...
# 1       3917    m3a3  How many months ago did he/she stop living wit...
# 2       3918   m3a3a                  Who does child usually live with?
# 3       3919   m3a3b         Are child's foster parents related to you?
# 4       3920  m3a3b1  Does (person in A3A) receive any payment for t...
# 5       3921   m3a3c  About how many months has child been living th...
# 6       3922   m3a3d  Do you expect child to live with you again dur...
# 7       3923   m3a3e  About how many days did you see child in past ...
# 8       3924   m3a3f  Who does child live with when he/she is not li...
# 9       3925   m3a3g  How many days did child live with you out of t...
# 10      3926    m3a4  What is your relationship with child's father ...
# 11      3927   m3a4a  Are you romantically involved steadily or on-a...
# 12      3928  m3a4a1      Are you and father currently living together?
# 13      3929  m3a4a2  INT CHK: ARE MOTHER AND FATHER MARRIED AND LIV...
# 14      3930   m3a4b  How many nights a week do you and father usual...
# 15      3931  m3a4c2                        When did father die? (year)
# 16      3932   m3a4d                   What was the cause of his death?
# 17      3933   m3a4e                     Do you know who the father is?
# 18      3934    m3a5  INT CHK: WERE MOTHER AND FATHER UNMARRIED AT O...
# 19      3935  m3a5a1       When did you and father get married? (month)
#
#    question_number  multiple_answers
# 0               A2                 0
# 1               A3                 0
# 2              A3A                 0
# 3              A3B                 0
# 4             A3B1                 0
# 5              A3C                 0
# 6              A3D                 0
# 7              A3E                 0
# 8              A3F                 0
# 9              A3G                 0
# 10              A4                 0
# 11             A4A                 0
# 12            A4A1                 0
# 13            A4A2                 0
# 14             A4B                 0
# 15            A4C2                 0
# 16             A4D                 0
# 17             A4E                 0
# 18              A5                 0
# 19            A5A1                 0

# %%
def find_question(q_number):
    """finds where the question number appears in the text - only if it only appears once"""
    ps_text = []
    ps_idx = []
    ps_startswith = []
    for idx, p in enumerate(ps):
        if q_number+"." in p.get_text():
            if p.get_text().lstrip().startswith(q_number+"."):
                ps_text.append(p.get_text().lstrip())
                ps_idx.append(idx)
    if len(ps_idx)!=1:
        return np.nan, np.nan
    else:
        return ps_text[0].replace("\n"," ").strip(), ps_idx[0]

# %%
def find_probe(q_number):
    probe = re.findall('[A-Z]{,1}\d{,2}', q_number)[0]
    return find_question(probe)[0]

# %%
for i in range(len(df.question_number)):
    q_number = df.loc[i,'question_number']
    if re.match('^[A-Z]{,1}\d{,2}', q_number):
        df.loc[i,'probe'] = find_probe(q_number)
    else:
        df.loc[i,'probe'] = "None"

# %%
df['ps_text'], df['ps_idx'] = zip(*df['question_number'].map(find_question))

# %%
df
# Out:
#       position      name                                             varlab  \
# 0         3916      m3a2  How much of the time does the child live with ...
# 1         3917      m3a3  How many months ago did he/she stop living wit...
# 2         3918     m3a3a                  Who does child usually live with?
# 3         3919     m3a3b         Are child's foster parents related to you?
# 4         3920    m3a3b1  Does (person in A3A) receive any payment for t...
# 5         3921     m3a3c  About how many months has child been living th...
# 6         3922     m3a3d  Do you expect child to live with you again dur...
# 7         3923     m3a3e  About how many days did you see child in past ...
# 8         3924     m3a3f  Who does child live with when he/she is not li...
# 9         3925     m3a3g  How many days did child live with you out of t...
# 10        3926      m3a4  What is your relationship with child's father ...
# 11        3927     m3a4a  Are you romantically involved steadily or on-a...
# 12        3928    m3a4a1      Are you and father currently living together?
# 13        3929    m3a4a2  INT CHK: ARE MOTHER AND FATHER MARRIED AND LIV...
# 14        3930     m3a4b  How many nights a week do you and father usual...
# 15        3931    m3a4c2                        When did father die? (year)
# 16        3932     m3a4d                   What was the cause of his death?
# 17        3933     m3a4e                     Do you know who the father is?
# 18        3934      m3a5  INT CHK: WERE MOTHER AND FATHER UNMARRIED AT O...
# 19        3935    m3a5a1       When did you and father get married? (month)
# 20        3936    m3a5a2        When did you and father get married? (year)
# 21        3937      m3a6  INT CHK: WERE MOTHER AND FATHER LIVING APART A...
# 22        3938    m3a6a1  When did you and father start living together?...
# 23        3939    m3a6a2  When did you and father start living together?...
# 24        3940      m3a7  INT CHK: WERE MOTHER AND FATHER MARRIED AT ONE...
# 25        3941    m3a7a1  When did you and father get separated/divorced...
# 26        3942    m3a7a2  When did you and father get separated/divorced...
# 27        3943      m3a8  INT CHK: WERE MOTHER AND FATHER ROMANTICALLY I...
# 28        3944    m3a8a1  When did your romantic relationship with fathe...
# 29        3945    m3a8a2  When did your romantic relationship with fathe...
# ...        ...       ...                                                ...
# 1005      4921    m3k27e  How much did you receive in past year doing ot...
# 1006      4922   m3k27e1       Range of earnings from doing something else?
# 1007      4923    m3k27f  Was other type of payment received for doing s...
# 1008      4924  m3k27f_1  What did you get for doing something else: meals?
# 1009      4925  m3k27f_2  What did you get for doing something else: clo...
# 1010      4926  m3k27f_3  What did you get for doing something else: pla...
# 1011      4927  m3k27f_4  What did you get for doing something else: other?
# 1012      4928  m3k27f_5  What did you get for doing something else: chi...
# 1013      4929      m3l1  What was total household income (all sources) ...
# 1014      4930     m3l1a  What is the range of your total household income?
# 1015      4931      m3l2  In past year, have you given/loaned money to f...
# 1016      4932     m3l2a  In past year, how much money did you give/loan...
# 1017      4933      m3l3  INT CHK: IS MOTHER LIVING WITH FATHER OR CURRE...
# 1018      4934      m3l4     Do you or husband/partner have a bank account?
# 1019      4935     m3l4a  Is/are the account(s) in your name, his/her na...
# 1020      4936      m3l5      Do you or husband/partner have a credit card?
# 1021      4937     m3l5a   Is the card in your name, his/her name, or both?
# 1022      4938     m3l5b                      How does couple handle money?
# 1023      4939     m3l5c         Who in household is responsible for bills?
# 1024      4940     m3l5d                   Who in household controls money?
# 1025      4941      m3l6     Do you or husband/partner own a car/truck/van?
# 1026      4942     m3l6a  Can you rely on vehicle to get you to school/w...
# 1027      4943     m3l6b                    How much do you owe on vehicle?
# 1028      4944     m3l6c    How much could you get if you sold vehicle now?
# 1029      4945      m3l7                        Do you have a bank account?
# 1030      4946      m3l8                         Do you have a credit card?
# 1031      4947      m3l9                   Do you own a car, truck, or van?
# 1032      4948     m3l9a  Can you rely on vehicle to get you to work, sc...
# 1033      4949     m3l9b               How much do you owe on your vehicle?
# 1034      4950     m3l9c        How much could you get if you sold vehicle?
#
#      question_number  multiple_answers  \
# 0                 A2                 0
# 1                 A3                 0
# 2                A3A                 0
# 3                A3B                 0
# 4               A3B1                 0
# 5                A3C                 0
# 6                A3D                 0
# 7                A3E                 0
# 8                A3F                 0
# 9                A3G                 0
# 10                A4                 0
# 11               A4A                 0
# 12              A4A1                 0
# 13              A4A2                 0
# 14               A4B                 0
# 15              A4C2                 0
# 16               A4D                 0
# 17               A4E                 0
# 18                A5                 0
# 19              A5A1                 0
# 20              A5A2                 0
# 21                A6                 0
# 22              A6A1                 0
# 23              A6A2                 0
# 24                A7                 0
# 25              A7A1                 0
# 26              A7A2                 0
# 27                A8                 0
# 28              A8A1                 0
# 29              A8A2                 0
# ...              ...               ...
# 1005            K27E                 0
# 1006           K27E1                 0
# 1007            K27F                 0
# 1008            K27F                 1
# 1009            K27F                 1
# 1010            K27F                 1
# 1011            K27F                 1
# 1012            K27F                 1
# 1013              L1                 0
# 1014             L1A                 0
# 1015              L2                 0
# 1016             L2A                 0
# 1017              L3                 0
# 1018              L4                 0
# 1019             L4A                 0
# 1020              L5                 0
# 1021             L5A                 0
# 1022             L5B                 0
# 1023             L5C                 0
# 1024             L5D                 0
# 1025              L6                 0
# 1026             L6A                 0
# 1027             L6B                 0
# 1028             L6C                 0
# 1029              L7                 0
# 1030              L8                 0
# 1031              L9                 0
# 1032             L9A                 0
# 1033             L9B                 0
# 1034             L9C                 0
#
#                                                   probe  \
# 0     A2.           How much of the time does (CHILD...
# 1     A3.           How many months ago did (he/she)...
# 2     A3.           How many months ago did (he/she)...
# 3     A3.           How many months ago did (he/she)...
# 4     A3.           How many months ago did (he/she)...
# 5     A3.           How many months ago did (he/she)...
# 6     A3.           How many months ago did (he/she)...
# 7     A3.           How many months ago did (he/she)...
# 8     A3.           How many months ago did (he/she)...
# 9     A3.           How many months ago did (he/she)...
# 10    A4.           Next, I have a few questions abo...
# 11    A4.           Next, I have a few questions abo...
# 12    A4.           Next, I have a few questions abo...
# 13    A4.           Next, I have a few questions abo...
# 14    A4.           Next, I have a few questions abo...
# 15    A4.           Next, I have a few questions abo...
# 16    A4.           Next, I have a few questions abo...
# 17    A4.           Next, I have a few questions abo...
# 18    A5.           WERE MOTHER AND FATHER UNMARRIED...
# 19    A5.           WERE MOTHER AND FATHER UNMARRIED...
# 20    A5.           WERE MOTHER AND FATHER UNMARRIED...
# 21    A6.           WERE MOTHER AND FATHER LIVING AP...
# 22    A6.           WERE MOTHER AND FATHER LIVING AP...
# 23    A6.           WERE MOTHER AND FATHER LIVING AP...
# 24    A7.           WERE MOTHER AND FATHER MARRIED A...
# 25    A7.           WERE MOTHER AND FATHER MARRIED A...
# 26    A7.           WERE MOTHER AND FATHER MARRIED A...
# 27    A8.           WERE MOTHER AND FATHER ROMANTICA...
# 28    A8.           WERE MOTHER AND FATHER ROMANTICA...
# 29    A8.           WERE MOTHER AND FATHER ROMANTICA...
# ...                                                 ...
# 1005                                                NaN
# 1006                                                NaN
# 1007                                                NaN
# 1008                                                NaN
# 1009                                                NaN
# 1010                                                NaN
# 1011                                                NaN
# 1012                                                NaN
# 1013  L1.           In the past 12 months, what was ...
# 1014  L1.           In the past 12 months, what was ...
# 1015  L2.           In the past 12 months, have you ...
# 1016  L2.           In the past 12 months, have you ...
# 1017  L3.           IS MOTHER LIVING WITH FATHER OR ...
# 1018  L4.           Do you or your (husband/partner)...
# 1019  L4.           Do you or your (husband/partner)...
# 1020  L5.           Do you or your (husband/partner)...
# 1021  L5.           Do you or your (husband/partner)...
# 1022  L5.           Do you or your (husband/partner)...
# 1023  L5.           Do you or your (husband/partner)...
# 1024  L5.           Do you or your (husband/partner)...
# 1025  L6.           Do you or your (husband/partner)...
# 1026  L6.           Do you or your (husband/partner)...
# 1027  L6.           Do you or your (husband/partner)...
# 1028  L6.           Do you or your (husband/partner)...
# 1029          L7.           Do you have a bank account?
# 1030  L8.           Do you have a credit card?  Incl...
# 1031      L9.           Do you own a car, truck or van?
# 1032      L9.           Do you own a car, truck or van?
# 1033      L9.           Do you own a car, truck or van?
# 1034      L9.           Do you own a car, truck or van?
#
#                                                 ps_text  ps_idx
# 0     A2.           How much of the time does (CHILD...    79.0
# 1     A3.           How many months ago did (he/she)...    95.0
# 2     A3A.        Who does (CHILD) (usually) live with?   105.0
# 3     A3B.        Are (CHILD's) foster parents relat...   119.0
# 4     A3B1.      Does (PERSON IN A3A) receive any ki...   128.0
# 5     A3C.        About how many months has (CHILD) ...   136.0
# 6     A3D.        Do you expect (CHILD) to live with...   143.0
# 7     A3E.        About how many days did you see (C...   149.0
# 8     A3F.        Who does (CHILD) live with when (h...   156.0
# 9     A3G.        How many days did (CHILD) live wit...   166.0
# 10    A4.           Next, I have a few questions abo...   175.0
# 11    A4A.        Would you say you are romantically...   190.0
# 12    A4A1.      Are you and (FATHER) currently livi...   197.0
# 13    A4A2.      ARE MOTHER AND FATHER MARRIED AND L...   205.0
# 14    A4B.        How many nights a week do you and ...   211.0
# 15                                                  NaN     NaN
# 16         A4D.        What was the cause of his death?   231.0
# 17           A4E.        Do you know who the father is?   243.0
# 18    A5.           WERE MOTHER AND FATHER UNMARRIED...   252.0
# 19                                                  NaN     NaN
# 20                                                  NaN     NaN
# 21    A6.           WERE MOTHER AND FATHER LIVING AP...   268.0
# 22                                                  NaN     NaN
# 23                                                  NaN     NaN
# 24    A7.           WERE MOTHER AND FATHER MARRIED A...   284.0
# 25                                                  NaN     NaN
# 26                                                  NaN     NaN
# 27    A8.           WERE MOTHER AND FATHER ROMANTICA...   300.0
# 28                                                  NaN     NaN
# 29                                                  NaN     NaN
# ...                                                 ...     ...
# 1005                                                NaN     NaN
# 1006                                                NaN     NaN
# 1007                                                NaN     NaN
# 1008                                                NaN     NaN
# 1009                                                NaN     NaN
# 1010                                                NaN     NaN
# 1011                                                NaN     NaN
# 1012                                                NaN     NaN
# 1013  L1.           In the past 12 months, what was ...  7462.0
# 1014  L1A.        I just need to know a range.  Can ...  7472.0
# 1015  L2.           In the past 12 months, have you ...  7487.0
# 1016  L2A.        All together, during the past 12 m...  7492.0
# 1017  L3.           IS MOTHER LIVING WITH FATHER OR ...  7500.0
# 1018  L4.           Do you or your (husband/partner)...  7507.0
# 1019  L4A.         (Is the account/Are the accounts)...  7514.0
# 1020  L5.           Do you or your (husband/partner)...  7523.0
# 1021  L5A.         Is the card in your name, (his/he...  7528.0
# 1022  L5B.        Couples handle money differently. ...  7540.0
# 1023  L5C.        Couples also make different arrang...  7552.0
# 1024  L5D.        Who would you say controls the mon...  7593.0
# 1025  L6.           Do you or your (husband/partner)...  7607.0
# 1026  L6A.        Can you rely on the (car/truck/van...  7614.0
# 1027  L6B.        How much do you owe on your (car/t...  7631.0
# 1028  L6C.        About how much could you get if yo...  7641.0
# 1029          L7.           Do you have a bank account?  7650.0
# 1030  L8.           Do you have a credit card?  Incl...  7656.0
# 1031      L9.           Do you own a car, truck or van?  7662.0
# 1032  L9A.        Can you rely on the (car/truck/van...  7669.0
# 1033  L9B.        How much do you owe on your (car/t...  7677.0
# 1034  L9C.        About how much could you get if yo...  7687.0
#
# [1035 rows x 8 columns]

# %%
np.isnan(df.ps_idx).sum() #number of questions where the question number doesn't appear or appears more than once
# Out:
# 338

# %%
print(df.ps_text[11])
print(df.ps_idx[11])
# Out:
# A4A.        Would you say you are romantically involved on a steady basis, or are you in an on-again - off-again relationship?
# 190.0

# %%
#get index of <p> tag for the next question so we can split the questions (can't just shift because some questions have more than one answer or missing values)
all_idx=np.array(df.ps_idx)
all_idx=all_idx[~np.isnan(all_idx)]
all_idx=np.append(all_idx, [len(ps)])
df['ps_idx_next']=df.ps_idx.apply(lambda x: all_idx[all_idx > x].min() if ~np.isnan(x) else np.nan)

# %%
a3 = ps[107:115]

# %%
a3
# Out:
# [<p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             BIOLOGICAL FATHER....................................... 1<b>
#  </b></span><span style="font-family:Wingdings;color:black;layout-grid-mode:
#  line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3C</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             MATERNAL GRANDPARENT(S)...................... 2
#  </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             PATERNAL GRANDPARENT(S)...................... 3
#  </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             OTHER RELATIVE(S)......................................... 4
#  </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             FRIEND.................................................................. 5
#  </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             FOSTER CARE.................................................... 6</span></p>,
#  <p class="MsoNormal"><span style="color:black;layout-grid-mode:line">                             ADOPTIVE
#  PARENT........................................... 7 </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> </span><b><span style="font-size:
#  10.0pt;color:black;layout-grid-mode:line">THANK MOTHER AND</span></b></p>,
#  <p class="MsoNormal" style="margin-left:1.0in"><span style="color:black;
#  layout-grid-mode:line">                                                                                               </span><b><span style="font-size:10.0pt;color:black;layout-grid-mode:line">END INTERVIEW.</span></b></p>]

# %%
for p in a3:
    print(p)
# Out:
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             BIOLOGICAL FATHER....................................... 1<b>
# </b></span><span style="font-family:Wingdings;color:black;layout-grid-mode:
# line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3C</b></span></p>
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             MATERNAL GRANDPARENT(S)...................... 2
# </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             PATERNAL GRANDPARENT(S)...................... 3
# </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             OTHER RELATIVE(S)......................................... 4
# </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             FRIEND.................................................................. 5
# </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             FOSTER CARE.................................................... 6</span></p>
# <p class="MsoNormal"><span style="color:black;layout-grid-mode:line">                             ADOPTIVE
# PARENT........................................... 7 </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> </span><b><span style="font-size:
# 10.0pt;color:black;layout-grid-mode:line">THANK MOTHER AND</span></b></p>
# <p class="MsoNormal" style="margin-left:1.0in"><span style="color:black;
# layout-grid-mode:line">                                                                                               </span><b><span style="font-size:10.0pt;color:black;layout-grid-mode:line">END INTERVIEW.</span></b></p>

# %%
consequitivedots = re.compile(r'\.{3,}')

# %%
for p in a3:
    if len(p.find_all(string = consequitivedots))>0:
        print(p)
# Out:
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             BIOLOGICAL FATHER....................................... 1<b>
# </b></span><span style="font-family:Wingdings;color:black;layout-grid-mode:
# line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3C</b></span></p>
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             MATERNAL GRANDPARENT(S)...................... 2
# </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             PATERNAL GRANDPARENT(S)...................... 3
# </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             OTHER RELATIVE(S)......................................... 4
# </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             FRIEND.................................................................. 5
# </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>
# <p class="MsoNormal" style="line-height:150%"><span style="color:black;
# layout-grid-mode:line">                             FOSTER CARE.................................................... 6</span></p>
# <p class="MsoNormal"><span style="color:black;layout-grid-mode:line">                             ADOPTIVE
# PARENT........................................... 7 </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> </span><b><span style="font-size:
# 10.0pt;color:black;layout-grid-mode:line">THANK MOTHER AND</span></b></p>

# %%
answers = [p for p in a3 if len(p.find_all(string = consequitivedots))>0]

# %%
answers
# Out:
# [<p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             BIOLOGICAL FATHER....................................... 1<b>
#  </b></span><span style="font-family:Wingdings;color:black;layout-grid-mode:
#  line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3C</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             MATERNAL GRANDPARENT(S)...................... 2
#  </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             PATERNAL GRANDPARENT(S)...................... 3
#  </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             OTHER RELATIVE(S)......................................... 4
#  </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             FRIEND.................................................................. 5
#  </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> <b>GO TO A3B1</b></span></p>,
#  <p class="MsoNormal" style="line-height:150%"><span style="color:black;
#  layout-grid-mode:line">                             FOSTER CARE.................................................... 6</span></p>,
#  <p class="MsoNormal"><span style="color:black;layout-grid-mode:line">                             ADOPTIVE
#  PARENT........................................... 7 </span><span style="font-family:Wingdings;color:black;layout-grid-mode:line">è</span><span style="color:black;layout-grid-mode:line"> </span><b><span style="font-size:
#  10.0pt;color:black;layout-grid-mode:line">THANK MOTHER AND</span></b></p>]

# %%
print(answers[0].prettify())
# Out:
# <p class="MsoNormal" style="line-height:150%">
#  <span style="color:black;
# layout-grid-mode:line">
#   BIOLOGICAL FATHER....................................... 1
#   <b>
#   </b>
#  </span>
#  <span style="font-family:Wingdings;color:black;layout-grid-mode:
# line">
#   è
#  </span>
#  <span style="color:black;layout-grid-mode:line">
#   <b>
#    GO TO A3C
#   </b>
#  </span>
# </p>

# %%
answers = [p for p in a3 if len(p.find_all(string = consequitivedots))>0]
for a in answers:
    print(a.get_text().split(".")[0])
    print(a.get_text().split(".")[-1])
# Out:
#                              BIOLOGICAL FATHER
#  1
# è GO TO A3C
#                              MATERNAL GRANDPARENT(S)
#  2
# è GO TO A3B1
#                              PATERNAL GRANDPARENT(S)
#  3
# è GO TO A3B1
#                              OTHER RELATIVE(S)
#  4
# è GO TO A3B1
#                              FRIEND
#  5
# è GO TO A3B1
#                              FOSTER CARE
#  6
#                              ADOPTIVE
# PARENT
#  7 è THANK MOTHER AND

# %%
def clean_text(string):
    return string.replace("\n"," ").strip()

def get_answers(start_idx,stop_idx):
    if np.isnan(start_idx) or np.isnan(stop_idx):
        return ([],0)
    else:
        answers = [p for p in ps[int(start_idx):int(stop_idx)] if len(p.find_all(string = consequitivedots))>0]
        answers = [(clean_text(a.get_text().split(".")[0]),clean_text(a.get_text().split(".")[-1])) for a in answers]
        return(answers,len(answers))

# %%
df['answers'], df['n_answers'] = zip(*map(get_answers, df['ps_idx'], df['ps_idx_next']))

# %%
x = 0
while x < len(df.answers):
    ans = df.answers[x]
    for i in range(len(ans)): #for each answer choice,
        s = ans[i][1]        # store number string
        a = re.sub('è',' --> ', s) # sub the arrow in for skip pattern
        t = (ans[i][0],a) # create a new tuple with arrow
        ans[i] = t
    for y in range(len(ans)):
        df.loc[x,'val{0}'.format(y)] = ans[y][1] #create new 'val(y)' column
        df.loc[x,'lab{0}'.format(y)] = ans[y][0] #create new 'lab(y)' column
        
    x += 1

# %%
df.head(10)
# Out:
#    position    name                                             varlab  \
# 0      3916    m3a2  How much of the time does the child live with ...
# 1      3917    m3a3  How many months ago did he/she stop living wit...
# 2      3918   m3a3a                  Who does child usually live with?
# 3      3919   m3a3b         Are child's foster parents related to you?
# 4      3920  m3a3b1  Does (person in A3A) receive any payment for t...
# 5      3921   m3a3c  About how many months has child been living th...
# 6      3922   m3a3d  Do you expect child to live with you again dur...
# 7      3923   m3a3e  About how many days did you see child in past ...
# 8      3924   m3a3f  Who does child live with when he/she is not li...
# 9      3925   m3a3g  How many days did child live with you out of t...
#
#   question_number  multiple_answers  \
# 0              A2                 0
# 1              A3                 0
# 2             A3A                 0
# 3             A3B                 0
# 4            A3B1                 0
# 5             A3C                 0
# 6             A3D                 0
# 7             A3E                 0
# 8             A3F                 0
# 9             A3G                 0
#
#                                                probe  \
# 0  A2.           How much of the time does (CHILD...
# 1  A3.           How many months ago did (he/she)...
# 2  A3.           How many months ago did (he/she)...
# 3  A3.           How many months ago did (he/she)...
# 4  A3.           How many months ago did (he/she)...
# 5  A3.           How many months ago did (he/she)...
# 6  A3.           How many months ago did (he/she)...
# 7  A3.           How many months ago did (he/she)...
# 8  A3.           How many months ago did (he/she)...
# 9  A3.           How many months ago did (he/she)...
#
#                                              ps_text  ps_idx  ps_idx_next  \
# 0  A2.           How much of the time does (CHILD...    79.0         95.0
# 1  A3.           How many months ago did (he/she)...    95.0        105.0
# 2  A3A.        Who does (CHILD) (usually) live with?   105.0        119.0
# 3  A3B.        Are (CHILD's) foster parents relat...   119.0        128.0
# 4  A3B1.      Does (PERSON IN A3A) receive any ki...   128.0        136.0
# 5  A3C.        About how many months has (CHILD) ...   136.0        143.0
# 6  A3D.        Do you expect (CHILD) to live with...   143.0        149.0
# 7  A3E.        About how many days did you see (C...   149.0        156.0
# 8  A3F.        Who does (CHILD) live with when (h...   156.0        166.0
# 9  A3G.        How many days did (CHILD) live wit...   166.0        175.0
#
#                                              answers  ...    val122 lab122  \
# 0  [(All or most of the time,, 1  -->  GO TO A4),...  ...       NaN    NaN
# 1                                  [(THE TIME, -10)]  ...       NaN    NaN
# 2  [(BIOLOGICAL FATHER, 1  -->  GO TO A3C), (MATE...  ...       NaN    NaN
# 3                                [(YES, 1), (NO, 2)]  ...       NaN    NaN
# 4  [(YES, 1), (NO, 2), (DON’T KNOW, -2), (REFUSED...  ...       NaN    NaN
# 5                         [(LESS THAN ONE MONTH, 0)]  ...       NaN    NaN
# 6                                [(YES, 1), (NO, 2)]  ...       NaN    NaN
# 7                                        [(NONE, 0)]  ...       NaN    NaN
# 8  [(BIOLOGICAL FATHER, 1), (MATERNAL GRANDPARENT...  ...       NaN    NaN
# 9                                                 []  ...       NaN    NaN
#
#   val123 lab123 val124 lab124 val125 lab125 val126 lab126
# 0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [10 rows x 265 columns]

# %%
df.probe
# Out:
# 0       A2.           How much of the time does (CHILD...
# 1       A3.           How many months ago did (he/she)...
# 2       A3.           How many months ago did (he/she)...
# 3       A3.           How many months ago did (he/she)...
# 4       A3.           How many months ago did (he/she)...
# 5       A3.           How many months ago did (he/she)...
# 6       A3.           How many months ago did (he/she)...
# 7       A3.           How many months ago did (he/she)...
# 8       A3.           How many months ago did (he/she)...
# 9       A3.           How many months ago did (he/she)...
# 10      A4.           Next, I have a few questions abo...
# 11      A4.           Next, I have a few questions abo...
# 12      A4.           Next, I have a few questions abo...
# 13      A4.           Next, I have a few questions abo...
# 14      A4.           Next, I have a few questions abo...
# 15      A4.           Next, I have a few questions abo...
# 16      A4.           Next, I have a few questions abo...
# 17      A4.           Next, I have a few questions abo...
# 18      A5.           WERE MOTHER AND FATHER UNMARRIED...
# 19      A5.           WERE MOTHER AND FATHER UNMARRIED...
# 20      A5.           WERE MOTHER AND FATHER UNMARRIED...
# 21      A6.           WERE MOTHER AND FATHER LIVING AP...
# 22      A6.           WERE MOTHER AND FATHER LIVING AP...
# 23      A6.           WERE MOTHER AND FATHER LIVING AP...
# 24      A7.           WERE MOTHER AND FATHER MARRIED A...
# 25      A7.           WERE MOTHER AND FATHER MARRIED A...
# 26      A7.           WERE MOTHER AND FATHER MARRIED A...
# 27      A8.           WERE MOTHER AND FATHER ROMANTICA...
# 28      A8.           WERE MOTHER AND FATHER ROMANTICA...
# 29      A8.           WERE MOTHER AND FATHER ROMANTICA...
#                               ...
# 1005                                                  NaN
# 1006                                                  NaN
# 1007                                                  NaN
# 1008                                                  NaN
# 1009                                                  NaN
# 1010                                                  NaN
# 1011                                                  NaN
# 1012                                                  NaN
# 1013    L1.           In the past 12 months, what was ...
# 1014    L1.           In the past 12 months, what was ...
# 1015    L2.           In the past 12 months, have you ...
# 1016    L2.           In the past 12 months, have you ...
# 1017    L3.           IS MOTHER LIVING WITH FATHER OR ...
# 1018    L4.           Do you or your (husband/partner)...
# 1019    L4.           Do you or your (husband/partner)...
# 1020    L5.           Do you or your (husband/partner)...
# 1021    L5.           Do you or your (husband/partner)...
# 1022    L5.           Do you or your (husband/partner)...
# 1023    L5.           Do you or your (husband/partner)...
# 1024    L5.           Do you or your (husband/partner)...
# 1025    L6.           Do you or your (husband/partner)...
# 1026    L6.           Do you or your (husband/partner)...
# 1027    L6.           Do you or your (husband/partner)...
# 1028    L6.           Do you or your (husband/partner)...
# 1029            L7.           Do you have a bank account?
# 1030    L8.           Do you have a credit card?  Incl...
# 1031        L9.           Do you own a car, truck or van?
# 1032        L9.           Do you own a car, truck or van?
# 1033        L9.           Do you own a car, truck or van?
# 1034        L9.           Do you own a car, truck or van?
# Name: probe, Length: 1035, dtype: object

# %%
df.columns.get_loc('val0')
# Out:
# 11

# %%
i = 0
while i < len(df.ps_text):
    if df.multiple_answers[i] == 1:
        text = ''
        df.loc[i,'probe'] = df.loc[i,'ps_text']
        values = df.loc[i,'val0':].tolist()
        part = (df.name[i].lstrip('m3').split('_')[1])
        match = re.match('[0-9]{1,3}',part)
        if match:
            if part in values:
                index = values.index(part) +1
                text = values[index]
        df.loc[i,'ps_text'] = text
    i += 1

# %%
print(df.ps_text[11])
# Out:
# A4A.        Would you say you are romantically involved on a steady basis, or are you in an on-again - off-again relationship?

# %%
df.answers[11]
# Out:
# [('STEADY', '1'), ('ON-AGAIN, OFF-AGAIN', '2')]

# %%
df.head(20)
# Out:
#     position    name                                             varlab  \
# 0       3916    m3a2  How much of the time does the child live with ...
# 1       3917    m3a3  How many months ago did he/she stop living wit...
# 2       3918   m3a3a                  Who does child usually live with?
# 3       3919   m3a3b         Are child's foster parents related to you?
# 4       3920  m3a3b1  Does (person in A3A) receive any payment for t...
# 5       3921   m3a3c  About how many months has child been living th...
# 6       3922   m3a3d  Do you expect child to live with you again dur...
# 7       3923   m3a3e  About how many days did you see child in past ...
# 8       3924   m3a3f  Who does child live with when he/she is not li...
# 9       3925   m3a3g  How many days did child live with you out of t...
# 10      3926    m3a4  What is your relationship with child's father ...
# 11      3927   m3a4a  Are you romantically involved steadily or on-a...
# 12      3928  m3a4a1      Are you and father currently living together?
# 13      3929  m3a4a2  INT CHK: ARE MOTHER AND FATHER MARRIED AND LIV...
# 14      3930   m3a4b  How many nights a week do you and father usual...
# 15      3931  m3a4c2                        When did father die? (year)
# 16      3932   m3a4d                   What was the cause of his death?
# 17      3933   m3a4e                     Do you know who the father is?
# 18      3934    m3a5  INT CHK: WERE MOTHER AND FATHER UNMARRIED AT O...
# 19      3935  m3a5a1       When did you and father get married? (month)
#
#    question_number  multiple_answers  \
# 0               A2                 0
# 1               A3                 0
# 2              A3A                 0
# 3              A3B                 0
# 4             A3B1                 0
# 5              A3C                 0
# 6              A3D                 0
# 7              A3E                 0
# 8              A3F                 0
# 9              A3G                 0
# 10              A4                 0
# 11             A4A                 0
# 12            A4A1                 0
# 13            A4A2                 0
# 14             A4B                 0
# 15            A4C2                 0
# 16             A4D                 0
# 17             A4E                 0
# 18              A5                 0
# 19            A5A1                 0
#
#                                                 probe  \
# 0   A2.           How much of the time does (CHILD...
# 1   A3.           How many months ago did (he/she)...
# 2   A3.           How many months ago did (he/she)...
# 3   A3.           How many months ago did (he/she)...
# 4   A3.           How many months ago did (he/she)...
# 5   A3.           How many months ago did (he/she)...
# 6   A3.           How many months ago did (he/she)...
# 7   A3.           How many months ago did (he/she)...
# 8   A3.           How many months ago did (he/she)...
# 9   A3.           How many months ago did (he/she)...
# 10  A4.           Next, I have a few questions abo...
# 11  A4.           Next, I have a few questions abo...
# 12  A4.           Next, I have a few questions abo...
# 13  A4.           Next, I have a few questions abo...
# 14  A4.           Next, I have a few questions abo...
# 15  A4.           Next, I have a few questions abo...
# 16  A4.           Next, I have a few questions abo...
# 17  A4.           Next, I have a few questions abo...
# 18  A5.           WERE MOTHER AND FATHER UNMARRIED...
# 19  A5.           WERE MOTHER AND FATHER UNMARRIED...
#
#                                               ps_text  ps_idx  ps_idx_next  \
# 0   A2.           How much of the time does (CHILD...    79.0         95.0
# 1   A3.           How many months ago did (he/she)...    95.0        105.0
# 2   A3A.        Who does (CHILD) (usually) live with?   105.0        119.0
# 3   A3B.        Are (CHILD's) foster parents relat...   119.0        128.0
# 4   A3B1.      Does (PERSON IN A3A) receive any ki...   128.0        136.0
# 5   A3C.        About how many months has (CHILD) ...   136.0        143.0
# 6   A3D.        Do you expect (CHILD) to live with...   143.0        149.0
# 7   A3E.        About how many days did you see (C...   149.0        156.0
# 8   A3F.        Who does (CHILD) live with when (h...   156.0        166.0
# 9   A3G.        How many days did (CHILD) live wit...   166.0        175.0
# 10  A4.           Next, I have a few questions abo...   175.0        190.0
# 11  A4A.        Would you say you are romantically...   190.0        197.0
# 12  A4A1.      Are you and (FATHER) currently livi...   197.0        205.0
# 13  A4A2.      ARE MOTHER AND FATHER MARRIED AND L...   205.0        211.0
# 14  A4B.        How many nights a week do you and ...   211.0        231.0
# 15                                                NaN     NaN          NaN
# 16       A4D.        What was the cause of his death?   231.0        243.0
# 17         A4E.        Do you know who the father is?   243.0        252.0
# 18  A5.           WERE MOTHER AND FATHER UNMARRIED...   252.0        268.0
# 19                                                NaN     NaN          NaN
#
#                                               answers  ...    val122 lab122  \
# 0   [(All or most of the time,, 1  -->  GO TO A4),...  ...       NaN    NaN
# 1                                   [(THE TIME, -10)]  ...       NaN    NaN
# 2   [(BIOLOGICAL FATHER, 1  -->  GO TO A3C), (MATE...  ...       NaN    NaN
# 3                                 [(YES, 1), (NO, 2)]  ...       NaN    NaN
# 4   [(YES, 1), (NO, 2), (DON’T KNOW, -2), (REFUSED...  ...       NaN    NaN
# 5                          [(LESS THAN ONE MONTH, 0)]  ...       NaN    NaN
# 6                                 [(YES, 1), (NO, 2)]  ...       NaN    NaN
# 7                                         [(NONE, 0)]  ...       NaN    NaN
# 8   [(BIOLOGICAL FATHER, 1), (MATERNAL GRANDPARENT...  ...       NaN    NaN
# 9                                                  []  ...       NaN    NaN
# 10  [(IOWA         Married,, 1  -->  GO TO A4A), (...  ...       NaN    NaN
# 11            [(STEADY, 1), (ON-AGAIN, OFF-AGAIN, 2)]  ...       NaN    NaN
# 12  [(All or most of the time,, 1), (Some of the t...  ...       NaN    NaN
# 13                 [(YES, 1  -->  GO TO A5), (NO, 2)]  ...       NaN    NaN
# 14                         [(NONE, 0), (REFUSED, -1)]  ...       NaN    NaN
# 15                                                 []  ...       NaN    NaN
# 16  [(WON’T DISCUSS, 1), (ILLNESS (NOT SPECIFIED),...  ...       NaN    NaN
# 17                [(YES, 1), (NO, 2  -->  GO TO A10)]  ...       NaN    NaN
# 18                 [(YES, 1), (NO, 2  -->  GO TO A6)]  ...       NaN    NaN
# 19                                                 []  ...       NaN    NaN
#
#    val123 lab123 val124 lab124 val125 lab125 val126 lab126
# 0     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 13    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 14    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 15    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 16    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 17    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [20 rows x 265 columns]

# %%
df.drop(['answers','n_answers','multiple_answers','question_number','ps_idx','ps_idx_next'],axis=1,inplace=True)

# %%
df.head(20)
# Out:
#     position    name                                             varlab  \
# 0       3916    m3a2  How much of the time does the child live with ...
# 1       3917    m3a3  How many months ago did he/she stop living wit...
# 2       3918   m3a3a                  Who does child usually live with?
# 3       3919   m3a3b         Are child's foster parents related to you?
# 4       3920  m3a3b1  Does (person in A3A) receive any payment for t...
# 5       3921   m3a3c  About how many months has child been living th...
# 6       3922   m3a3d  Do you expect child to live with you again dur...
# 7       3923   m3a3e  About how many days did you see child in past ...
# 8       3924   m3a3f  Who does child live with when he/she is not li...
# 9       3925   m3a3g  How many days did child live with you out of t...
# 10      3926    m3a4  What is your relationship with child's father ...
# 11      3927   m3a4a  Are you romantically involved steadily or on-a...
# 12      3928  m3a4a1      Are you and father currently living together?
# 13      3929  m3a4a2  INT CHK: ARE MOTHER AND FATHER MARRIED AND LIV...
# 14      3930   m3a4b  How many nights a week do you and father usual...
# 15      3931  m3a4c2                        When did father die? (year)
# 16      3932   m3a4d                   What was the cause of his death?
# 17      3933   m3a4e                     Do you know who the father is?
# 18      3934    m3a5  INT CHK: WERE MOTHER AND FATHER UNMARRIED AT O...
# 19      3935  m3a5a1       When did you and father get married? (month)
#
#                                                 probe  \
# 0   A2.           How much of the time does (CHILD...
# 1   A3.           How many months ago did (he/she)...
# 2   A3.           How many months ago did (he/she)...
# 3   A3.           How many months ago did (he/she)...
# 4   A3.           How many months ago did (he/she)...
# 5   A3.           How many months ago did (he/she)...
# 6   A3.           How many months ago did (he/she)...
# 7   A3.           How many months ago did (he/she)...
# 8   A3.           How many months ago did (he/she)...
# 9   A3.           How many months ago did (he/she)...
# 10  A4.           Next, I have a few questions abo...
# 11  A4.           Next, I have a few questions abo...
# 12  A4.           Next, I have a few questions abo...
# 13  A4.           Next, I have a few questions abo...
# 14  A4.           Next, I have a few questions abo...
# 15  A4.           Next, I have a few questions abo...
# 16  A4.           Next, I have a few questions abo...
# 17  A4.           Next, I have a few questions abo...
# 18  A5.           WERE MOTHER AND FATHER UNMARRIED...
# 19  A5.           WERE MOTHER AND FATHER UNMARRIED...
#
#                                               ps_text               val0  \
# 0   A2.           How much of the time does (CHILD...   1  -->  GO TO A4
# 1   A3.           How many months ago did (he/she)...                -10
# 2   A3A.        Who does (CHILD) (usually) live with?  1  -->  GO TO A3C
# 3   A3B.        Are (CHILD's) foster parents relat...                  1
# 4   A3B1.      Does (PERSON IN A3A) receive any ki...                  1
# 5   A3C.        About how many months has (CHILD) ...                  0
# 6   A3D.        Do you expect (CHILD) to live with...                  1
# 7   A3E.        About how many days did you see (C...                  0
# 8   A3F.        Who does (CHILD) live with when (h...                  1
# 9   A3G.        How many days did (CHILD) live wit...                NaN
# 10  A4.           Next, I have a few questions abo...  1  -->  GO TO A4A
# 11  A4A.        Would you say you are romantically...                  1
# 12  A4A1.      Are you and (FATHER) currently livi...                  1
# 13  A4A2.      ARE MOTHER AND FATHER MARRIED AND L...   1  -->  GO TO A5
# 14  A4B.        How many nights a week do you and ...                  0
# 15                                                NaN                NaN
# 16       A4D.        What was the cause of his death?                  1
# 17         A4E.        Do you know who the father is?                  1
# 18  A5.           WERE MOTHER AND FATHER UNMARRIED...                  1
# 19                                                NaN                NaN
#
#                         lab0                val1                     lab1  \
# 0   All or most of the time,   2  -->  GO TO A3F  About half of the time,
# 1                   THE TIME                 NaN                      NaN
# 2          BIOLOGICAL FATHER  2  -->  GO TO A3B1  MATERNAL GRANDPARENT(S)
# 3                        YES                   2                       NO
# 4                        YES                   2                       NO
# 5        LESS THAN ONE MONTH                 NaN                      NaN
# 6                        YES                   2                       NO
# 7                       NONE                 NaN                      NaN
# 8          BIOLOGICAL FATHER                   2  MATERNAL GRANDPARENT(S)
# 9                        NaN                 NaN                      NaN
# 10     IOWA         Married,                   2   Romantically involved,
# 11                    STEADY                   2      ON-AGAIN, OFF-AGAIN
# 12  All or most of the time,                   2        Some of the time,
# 13                       YES                   2                       NO
# 14                      NONE                  -1                  REFUSED
# 15                       NaN                 NaN                      NaN
# 16             WON’T DISCUSS                   2  ILLNESS (NOT SPECIFIED)
# 17                       YES   2  -->  GO TO A10                       NO
# 18                       YES    2  -->  GO TO A6                       NO
# 19                       NaN                 NaN                      NaN
#
#                   val2  ...   val122 lab122 val123 lab123 val124 lab124  \
# 0     3  -->  GO TO A3  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 1                  NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 2   3  -->  GO TO A3B1  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 3                  NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 4                   -2  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 5                  NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 6                  NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 7                  NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 8                    3  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 9                  NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 10    3  -->  GO TO A7  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 11                 NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 12                   3  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 13                 NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 14                 NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 15                 NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 16                   3  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 17                 NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 18                 NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 19                 NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
#
#    val125 lab125 val126 lab126
# 0     NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN
# 5     NaN    NaN    NaN    NaN
# 6     NaN    NaN    NaN    NaN
# 7     NaN    NaN    NaN    NaN
# 8     NaN    NaN    NaN    NaN
# 9     NaN    NaN    NaN    NaN
# 10    NaN    NaN    NaN    NaN
# 11    NaN    NaN    NaN    NaN
# 12    NaN    NaN    NaN    NaN
# 13    NaN    NaN    NaN    NaN
# 14    NaN    NaN    NaN    NaN
# 15    NaN    NaN    NaN    NaN
# 16    NaN    NaN    NaN    NaN
# 17    NaN    NaN    NaN    NaN
# 18    NaN    NaN    NaN    NaN
# 19    NaN    NaN    NaN    NaN
#
# [20 rows x 259 columns]

# %%
df.to_csv(path_or_buf = "m3Qtext.csv")
